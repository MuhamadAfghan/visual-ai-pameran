# %% [markdown]
# # Train — Hand in Pocket Detection
#
# Training YOLO26m untuk deteksi tangan-di-saku (2 kelas): `hand_in_pocket`, `no_hand_in_pocket`.
#
# Prasyarat: jalankan **`01_data.ipynb`** dulu untuk membangun `processed/hand_in_pocket/`.
#
# **Output:** `best.pt` di `research/runs/detect/hand_in_pocket_yolo26m/weights/`. Setelah itu register di [registry.py](../../../src/cctv_insight_ai/models/registry.py) — lihat sel terakhir.
#
# ## Alur
# 1. Setup  2. Cek dataset  3. Training  4. Load run  5. Evaluasi  6. Visualisasi  7. Simpan artifact  8. Cara register

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline
from __future__ import annotations

import contextlib
import os
import random
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
from ultralytics import YOLO

NOTEBOOK_DIR = Path.cwd()
RESEARCH_DIR = NOTEBOOK_DIR.parents[1]
AI_DIR       = NOTEBOOK_DIR.parents[2]

PROC_DIR  = RESEARCH_DIR / 'datasets' / 'processed' / 'hand_in_pocket'
DATA_YAML = PROC_DIR / 'data.yaml'
BASE_MODEL = AI_DIR / 'models' / 'yolo26m.pt'
RUNS_DIR = RESEARCH_DIR / 'runs' / 'detect'
ARTIFACTS_DIR = RESEARCH_DIR / 'artifacts' / 'hand_in_pocket'
ARTIFACTS_DIR.mkdir(parents=True, exist_ok=True)

RUN_NAME = 'hand_in_pocket_yolo26m'
SEED = 42
CLASS_NAMES = ['hand_in_pocket', 'no_hand_in_pocket']

if not DATA_YAML.exists():
    raise FileNotFoundError(f'data.yaml nggak ada: {DATA_YAML}. Jalankan 01_data.ipynb dulu.')
if not BASE_MODEL.exists():
    raise FileNotFoundError(f'Base model nggak ada: {BASE_MODEL}')
print('data.yaml  :', DATA_YAML)
print('Base model :', BASE_MODEL)
# Out:
# data.yaml  : c:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\datasets\processed\hand_in_pocket\data.yaml
# Base model : c:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\models\yolo26m.pt

# %% [markdown]
# ## Cek Dataset
#
# Distribusi label per kelas per split.

# %%
def count_class_distribution(split):
    counts = {i: 0 for i in range(len(CLASS_NAMES))}
    d = PROC_DIR / split / 'labels'
    if not d.exists():
        return counts
    for lbl in d.glob('*.txt'):
        for line in lbl.read_text().splitlines():
            line = line.strip()
            if line:
                counts[int(line.split()[0])] = counts.get(int(line.split()[0]), 0) + 1
    return counts

dist = {s: count_class_distribution(s) for s in ('train', 'valid')}
dist_df = pd.DataFrame(dist).fillna(0).astype(int)
dist_df.index = [CLASS_NAMES[i] for i in dist_df.index]
print(dist_df.to_string())
# Out:
#                    train  valid
# hand_in_pocket       552    270
# no_hand_in_pocket    178     45

# %% [markdown]
# ## Training
#
# Set `RUN_TRAINING = True` kalau mau training. Default `False` biar nggak ke-trigger pas re-run.
# Default 50 epoch, patience 20. Ubah di `TRAIN_CFG` kalau perlu.

# %%
RUN_TRAINING = True

# Augmentasi diperkuat + epoch lebih banyak. Re-train di dataset_1 BERSIH (tanpa merge
# dataset_2: 255/259 gambar duplikat & 162 di antaranya bikin train/valid leakage).
# exist_ok=True -> timpa run lama supaya weights_path di registry.py tetap valid.
TRAIN_CFG = {
    'epochs': 150,
    'imgsz': 640,
    'batch': 8,
    'workers': 4,
    'patience': 40,
    'seed': SEED,
    'cos_lr': True,
    'close_mosaic': 10,
    # --- augmentasi (lebih kuat dari default) ---
    'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4,
    'degrees': 10.0, 'translate': 0.1, 'scale': 0.5, 'shear': 3.0,
    'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.15,
    'project': str(RUNS_DIR),
    'name': RUN_NAME,
    'exist_ok': True,
}


@contextlib.contextmanager
def _cwd(path):
    prev = os.getcwd(); os.chdir(str(path))
    try:
        yield
    finally:
        os.chdir(prev)


if RUN_TRAINING:
    with _cwd(AI_DIR / 'models'):
        model = YOLO(str(BASE_MODEL))
        result = model.train(data=str(DATA_YAML), **TRAIN_CFG)
    print('Training kelar:', result.save_dir)
else:
    print('Training di-skip. Set RUN_TRAINING=True kalau mau training.')
# Out:
# New https://pypi.org/project/ultralytics/8.4.71 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.38  Python-3.14.3 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=c:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\datasets\processed\hand_in_pocket\data.yaml, degrees=10.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=150, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.15, mode=train, model=c:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\models\yolo26m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=hand_in_pocket_yolo26m, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=40, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=c:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\runs\detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\runs\detect\hand_in_pocket_yolo26m, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=3.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   2801700  ultralytics.nn.modules.head.Detect           [2, 1, True, [256, 512, 512]]
# YOLO26m summary: 280 layers, 21,775,972 parameters, 21,775,972 gradients, 74.7 GFLOPs
#
# Transferred 756/768 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 28.338.8 MB/s, size: 41.6 KB)
# train: Scanning C:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\datasets\processed\hand_in_pocket\train\labels.cache... 449 images, 4 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 449/449 104.6Mit/s 0.0s
# val: Fast image access  (ping: 0.30.1 ms, read: 19.625.7 MB/s, size: 34.0 KB)
# val: Scanning C:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\datasets\processed\hand_in_pocket\valid\labels.cache... 205 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 205/205 26.9Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 124 weight(decay=0.0), 136 weight(decay=0.0005), 136 bias(decay=0.0)
# Plotting labels to C:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\runs\detect\hand_in_pocket_yolo26m\labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to C:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\runs\detect\hand_in_pocket_yolo26m
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/150      4.71G      2.014      7.939    0.01505          4        640: 100% ━━━━━━━━━━━━ 57/57 2.1it/s 27.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.2it/s 11.0s.3s
#                    all        205        315      0.231      0.156      0.083     0.0301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/150      4.88G      1.989       3.47    0.01558          4        640: 100% ━━━━━━━━━━━━ 57/57 3.4it/s 16.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.9it/s 2.2s0.2s
#                    all        205        315      0.358      0.161      0.162     0.0676
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/150      4.87G      2.105      3.103     0.0171          0        640: 100% ━━━━━━━━━━━━ 57/57 3.5it/s 16.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.8it/s 2.2s0.2s
#                    all        205        315      0.376      0.265      0.229     0.0692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/150      4.81G      2.218      2.948    0.01683          6        640: 100% ━━━━━━━━━━━━ 57/57 3.5it/s 16.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.8it/s 2.2s0.2s
#                    all        205        315      0.394      0.213       0.24       0.09
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/150      4.88G      2.216      2.823    0.01778          2        640: 100% ━━━━━━━━━━━━ 57/57 3.5it/s 16.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.8it/s 2.2s0.2s
#                    all        205        315      0.551      0.206      0.228     0.0746
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/150      4.89G      2.188      2.777    0.01718          3        640: 100% ━━━━━━━━━━━━ 57/57 3.5it/s 16.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.6it/s 2.3s0.2s
#                    all        205        315      0.439      0.261      0.284     0.0927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/150      4.88G      2.118      2.585     0.0172          1        640: 100% ━━━━━━━━━━━━ 57/57 3.4it/s 16.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.6it/s 2.3s0.2s
#                    all        205        315      0.341      0.248      0.209      0.073
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/150      4.88G      2.157      2.704    0.01765          2        640: 100% ━━━━━━━━━━━━ 57/57 3.4it/s 16.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.7it/s 2.3s0.2s
#                    all        205        315      0.419      0.304      0.283     0.0998
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/150      4.89G      2.169      2.535    0.01734          6        640: 100% ━━━━━━━━━━━━ 57/57 3.4it/s 16.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.6it/s 2.3s0.2s
#                    all        205        315      0.463      0.382      0.373      0.123
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/150      4.88G      2.192      2.415    0.01767          2        640: 100% ━━━━━━━━━━━━ 57/57 3.4it/s 16.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.7it/s 2.3s0.2s
#                    all        205        315      0.565      0.291      0.345      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/150      4.88G      2.114      2.412    0.01681          3        640: 100% ━━━━━━━━━━━━ 57/57 3.4it/s 16.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.6it/s 2.3s0.2s
#                    all        205        315      0.422      0.454      0.402       0.15
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/150       4.8G      2.136      2.294    0.01658          2        640: 100% ━━━━━━━━━━━━ 57/57 3.4it/s 16.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.6it/s 2.3s0.2s
#                    all        205        315      0.443      0.377      0.334      0.101
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/150      4.88G       2.16      2.207    0.01731          2        640: 100% ━━━━━━━━━━━━ 57/57 3.4it/s 16.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.6it/s 2.3s0.2s
#                    all        205        315      0.543      0.344      0.384      0.143
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/150      4.88G      2.121      2.265    0.01648          5        640: 100% ━━━━━━━━━━━━ 57/57 3.5it/s 16.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.6it/s 2.3s0.2s
#                    all        205        315      0.458      0.411      0.388      0.153
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/150      4.87G      2.084      2.286    0.01712          3        640: 100% ━━━━━━━━━━━━ 57/57 3.4it/s 16.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.6it/s 2.3s0.2s
#                    all        205        315      0.442      0.457      0.422      0.148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/150
640: 100% ━━━━━━━━━━━━ 57/57 3.7it/s 15.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.4it/s 2.0s0.1s
#                    all        205        315      0.613      0.692      0.627      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     137/150      4.89G       1.29     0.7977   0.009664          1        640: 100% ━━━━━━━━━━━━ 57/57 3.8it/s 15.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.6it/s 2.0s0.1s
#                    all        205        315      0.713      0.617      0.628      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     138/150      4.88G      1.233     0.7322   0.008498          1        640: 100% ━━━━━━━━━━━━ 57/57 3.6it/s 15.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.7it/s 1.9s0.1s
#                    all        205        315       0.61      0.746      0.629      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     139/150      4.89G      1.227       0.75   0.009723          1        640: 100% ━━━━━━━━━━━━ 57/57 3.5it/s 16.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.2it/s 2.5s0.2s
#                    all        205        315       0.64      0.719      0.646      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     140/150      4.81G      1.223     0.7694   0.009375          0        640: 100% ━━━━━━━━━━━━ 57/57 3.5it/s 16.1s0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.5it/s 2.0s0.1s
#                    all        205        315      0.648      0.743      0.648       0.29
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     141/150      4.87G       1.09     0.4699    0.00881          2        640: 100% ━━━━━━━━━━━━ 57/57 3.7it/s 15.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.5it/s 2.0s0.1s
#                    all        205        315      0.648      0.715      0.639      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     142/150      4.88G      1.107     0.4671   0.009564          1        640: 100% ━━━━━━━━━━━━ 57/57 3.8it/s 14.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.4it/s 2.0s0.1s
#                    all        205        315      0.645      0.708      0.632      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     143/150      4.87G      1.083     0.4462   0.009367          2        640: 100% ━━━━━━━━━━━━ 57/57 3.4it/s 16.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.2it/s 2.5s0.2s
#                    all        205        315        0.7      0.638      0.627      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     144/150      4.88G      1.087     0.4367   0.009299          2        640: 100% ━━━━━━━━━━━━ 57/57 3.4it/s 16.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.7it/s 2.3s0.2s
#                    all        205        315      0.697       0.64      0.616      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     145/150      4.87G      1.103     0.4408   0.009263          2        640: 100% ━━━━━━━━━━━━ 57/57 3.5it/s 16.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.8it/s 2.2s0.2s
#                    all        205        315      0.701      0.654      0.624      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     146/150      4.88G      1.083     0.4318   0.009241          2        640: 100% ━━━━━━━━━━━━ 57/57 3.7it/s 15.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.4it/s 2.0s0.1s
#                    all        205        315      0.712      0.648      0.621      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     147/150      4.88G      1.069     0.4426   0.008991          1        640: 100% ━━━━━━━━━━━━ 57/57 3.4it/s 16.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.3it/s 2.5s0.2s
#                    all        205        315      0.717      0.631      0.622      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     148/150       4.8G       1.08     0.4283   0.009397          2        640: 100% ━━━━━━━━━━━━ 57/57 3.4it/s 16.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.4it/s 2.4s0.2s
#                    all        205        315      0.713      0.639      0.618      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     149/150      4.88G      1.094     0.4489   0.009416          2        640: 100% ━━━━━━━━━━━━ 57/57 3.5it/s 16.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.5it/s 2.0s0.1s
#                    all        205        315       0.71      0.641      0.618      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     150/150      4.88G      1.125     0.4752   0.009618          2        640: 100% ━━━━━━━━━━━━ 57/57 3.6it/s 15.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.7it/s 2.8s0.2s
#                    all        205        315       0.72       0.65      0.625       0.28
#
# 150 epochs completed in 0.814 hours.
# Optimizer stripped from C:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\runs\detect\hand_in_pocket_yolo26m\weights\last.pt, 44.0MB
# Optimizer stripped from C:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\runs\detect\hand_in_pocket_yolo26m\weights\best.pt, 44.0MB
#
# Validating C:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\runs\detect\hand_in_pocket_yolo26m\weights\best.pt...
# Ultralytics 8.4.38  Python-3.14.3 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLO26m summary (fused): 132 layers, 20,350,994 parameters, 0 gradients, 67.9 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.3it/s 2.5s0.2s
#                    all        205        315      0.755      0.611      0.644      0.293
#         hand_in_pocket        190        270      0.841      0.644      0.735      0.253
#      no_hand_in_pocket         42         45      0.669      0.578      0.553      0.332
# Speed: 0.2ms preprocess, 6.1ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to C:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\runs\detect\hand_in_pocket_yolo26m
# Training kelar: C:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\runs\detect\hand_in_pocket_yolo26m

# %% [markdown]
# ## Load Run Terakhir

# %%
def find_latest_run(prefix):
    cands = [d for d in RUNS_DIR.glob(f'{prefix}*')
             if d.is_dir() and (d / 'weights' / 'best.pt').exists()]
    if not cands:
        raise FileNotFoundError(f"Belum ada run '{prefix}' di {RUNS_DIR}. Training dulu.")
    return max(cands, key=lambda d: d.stat().st_mtime)

run_dir = find_latest_run(RUN_NAME)
best_pt = run_dir / 'weights' / 'best.pt'
results_csv = run_dir / 'results.csv'
eval_model = YOLO(str(best_pt))
print('Run dir:', run_dir)
print('Kelas  :', eval_model.names)
# Out:
# Run dir: c:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\runs\detect\hand_in_pocket_yolo26m
# Kelas  : {0: 'hand_in_pocket', 1: 'no_hand_in_pocket'}

# %% [markdown]
# ## Evaluasi
#
# `model.val()` di split valid. Lihat mAP50, mAP50-95, Precision, Recall.

# %%
val = eval_model.val(data=str(DATA_YAML), imgsz=640, conf=0.25, verbose=False)
metrics = {
    'mAP50': round(float(val.box.map50), 3),
    'mAP50-95': round(float(val.box.map), 3),
    'Precision': round(float(val.box.mp), 3),
    'Recall': round(float(val.box.mr), 3),
}
print(pd.DataFrame([metrics]).to_string(index=False))
# Out:
# Ultralytics 8.4.38  Python-3.14.3 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLO26m summary (fused): 132 layers, 20,350,994 parameters, 0 gradients, 67.9 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 41.343.9 MB/s, size: 37.3 KB)
# val: Scanning C:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\datasets\processed\hand_in_pocket\valid\labels.cache... 205 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 205/205 45.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.8it/s 7.4s0.3s
#                    all        205        315      0.765       0.61      0.557      0.253
# Speed: 1.4ms preprocess, 15.7ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to C:\Users\istd.magang125\Documents\backend\runs\detect\val7
#  mAP50  mAP50-95  Precision  Recall
#  0.557     0.253      0.765    0.61

# %% [markdown]
# ## Visualisasi
#
# Training curves, per-class metrics, confusion matrix, dan sample prediksi (dari split valid).

# %%
df = pd.read_csv(results_csv)
df.columns = [c.strip() for c in df.columns]
curves = [('metrics/mAP50(B)', 'mAP50'), ('metrics/mAP50-95(B)', 'mAP50-95'),
          ('metrics/precision(B)', 'Precision'), ('metrics/recall(B)', 'Recall'),
          ('train/box_loss', 'Train Box Loss'), ('val/box_loss', 'Val Box Loss')]
available = [(c, l) for c, l in curves if c in df.columns]
rows_n = (len(available) + 1) // 2
fig, axes = plt.subplots(rows_n, 2, figsize=(12, 3 * rows_n)); axes = axes.flatten()
for ax, (col, label) in zip(axes, available):
    ax.plot(df['epoch'], df[col]); ax.set_title(label); ax.set_xlabel('epoch'); ax.grid(alpha=0.3)
for ax in axes[len(available):]:
    ax.axis('off')
plt.tight_layout(); plt.show()

# %%
class_indices = val.box.ap_class_index.astype(int).tolist()
per_class = []
for i, ci in enumerate(class_indices):
    p, r, ap50, ap = val.box.class_result(i)
    per_class.append({'class': val.names[ci], 'Precision': float(p), 'Recall': float(r),
                      'mAP50': float(ap50), 'mAP50-95': float(ap)})
per_class_df = pd.DataFrame(per_class)
print(per_class_df.round(3).to_string(index=False))

cm_path = Path(val.save_dir) / 'confusion_matrix_normalized.png'
if cm_path.exists():
    fig, ax = plt.subplots(figsize=(6, 5))
    ax.imshow(Image.open(cm_path)); ax.set_title('Confusion Matrix (normalized)'); ax.axis('off')
    plt.tight_layout(); plt.show()
# Out:
#             class  Precision  Recall  mAP50  mAP50-95
#    hand_in_pocket      0.857   0.641  0.660     0.223
# no_hand_in_pocket      0.673   0.578  0.454     0.283

# %%
N = 6
val_dir = PROC_DIR / 'valid' / 'images'
imgs = []
for e in ('*.jpg', '*.jpeg', '*.png'):
    imgs.extend(sorted(val_dir.glob(e)))
samples = random.Random(SEED).sample(imgs, min(N, len(imgs)))
cols = 2
rows_n = (len(samples) + cols - 1) // cols
fig, axes = plt.subplots(rows_n, cols, figsize=(14, 5 * rows_n)); axes = axes.flatten()
for ax, ip in zip(axes, samples):
    r = eval_model.predict(str(ip), conf=0.25, imgsz=640, verbose=False)[0]
    ax.imshow(r.plot()[..., ::-1]); ax.set_title(ip.name[:40], fontsize=8); ax.axis('off')
for ax in axes[len(samples):]:
    ax.axis('off')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Simpan Artifact

# %%
import json
import torch

speed = getattr(val, 'speed', {}) or {}
total_ms = sum(float(speed.get(k, 0.0)) for k in ('preprocess', 'inference', 'postprocess'))
eval_report = {
    'model_key': 'hand_in_pocket',
    'base_weight': str(BASE_MODEL),
    'run_dir': str(run_dir),
    'best_pt': str(best_pt),
    'data_yaml': str(DATA_YAML),
    'class_names': CLASS_NAMES,
    'seed': SEED,
    'train_cfg': TRAIN_CFG,
    'eval_cfg': {'conf': 0.25, 'imgsz': 640, 'split': 'val'},
    'device': 'cuda' if torch.cuda.is_available() else 'cpu',
    'metrics': {'mAP50': float(val.box.map50), 'mAP50-95': float(val.box.map),
                'precision': float(val.box.mp), 'recall': float(val.box.mr)},
    'speed_ms': {'total': total_ms, 'fps': (1000.0 / total_ms) if total_ms else 0.0},
}
(ARTIFACTS_DIR / 'eval_report.json').write_text(json.dumps(eval_report, indent=2), encoding='utf-8')
per_class_df.to_csv(ARTIFACTS_DIR / 'per_class_metrics.csv', index=False)
print('Saved ke', ARTIFACTS_DIR)
# Out:
# Saved ke c:\Users\istd.magang125\OneDrive - TMMIN\Documents\cctv-insight\ai\research\artifacts\hand_in_pocket

# %% [markdown]
# ## Cara Register ke Service
#
# Setelah `best.pt` jadi & metrik oke, tambahkan ke [registry.py](../../../src/cctv_insight_ai/models/registry.py):
#
# **1. Entry baru di `MODEL_REGISTRY`:**
# ```python
# "hand_in_pocket": ModelSpec(
#     name="hand_in_pocket_yolo26m",
#     version="2026.06.19",
#     weights_path=str(_RUNS_DIR / "hand_in_pocket_yolo26m" / "weights" / "best.pt"),
#     task_classes=[0, 1],
#     class_labels={
#         0: ClassLabel("hand_in_pocket"),
#         1: ClassLabel("no_hand_in_pocket"),
#     },
#     description="Hand-in-pocket detection (hand_in_pocket, no_hand_in_pocket)",
# ),
# ```
#
# **2. Tambah ke `CheckName` Literal:** `"hand_in_pocket_count",`
#
# **3. Entry baru di `CHECK_DEFINITIONS`:**
# ```python
# "hand_in_pocket_count": CheckDefinition(
#     name="hand_in_pocket_count",
#     model_key="hand_in_pocket",
#     categories=[
#         CheckCategory(key="hand_in_pocket", source_label="hand_in_pocket"),
#         CheckCategory(key="no_hand_in_pocket", source_label="no_hand_in_pocket"),
#     ],
#     description="Hitung tangan-di-saku (violation) vs tangan terlihat",
# ),
# ```
#
# Lalu `pytest tests/` (assert sinkronisasi CheckName/CHECK_DEFINITIONS) & smoke test gRPC.
#
# > **Catatan Fase B ("sambil berjalan"):** dataset ini single-frame, model hanya tahu "ada tangan-di-saku". Gating "sambil berjalan" butuh tracking + analisis gerak antar-frame — dikerjakan terpisah setelah Fase A.
